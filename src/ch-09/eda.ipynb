# %%
import torch
import torchvision
from d2l import torch as d2l

from gen_sine_data import SineData

# %%
train_data = SineData(True)
test_data = SineData(False)

print(len(train_data), len(test_data))
print(train_data.features.shape, test_data.labels.shape)

time, x = SineData._gen_sine_data()

d2l.plot(time, x, 'time', 'x', xlim=[1, 100000], figsize=(6,3))
# Out:
# 100000
# 99900
# 100
# <class 'torch.Tensor'>
# torch.Size([99900, 100])
# 100000
# 99900
# 100
# <class 'torch.Tensor'>
# torch.Size([99900, 100])
# 79920 19980
# torch.Size([79920, 100]) torch.Size([19980, 1])
# 100000

# %%
data.
# Out:
#   Cell In[3], line 1
#     data.
#          ^
# SyntaxError: invalid syntax
