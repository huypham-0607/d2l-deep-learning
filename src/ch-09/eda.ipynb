# %%
import torch
import torchvision
from d2l import torch as d2l

from gen_sine_data import SineData

# %%
data = SineData()
it = iter(data)

time, x = next(it)
print(type(time), time.dim())
print(type(x), x.dim())

d2l.plot(data.time, data.x, 'time', 'x', xlim=[1, 1000], figsize=(6,3))
# Out:
# <class 'torch.Tensor'> 0
# <class 'torch.Tensor'> 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 8
#       5 print(type(time), time.dim())
#       6 print(type(x), x.dim())
# ----> 8 d2l.torch.plot(data.time, data.x, 'time', 'x', xlim=[1, 1000], figsize=(6,3))
#
# File ~/miniconda3/envs/d2l/lib/python3.9/site-packages/torch/__init__.py:2745, in __getattr__(name)
#    2742 if name in _lazy_modules:
#    2743     return importlib.import_module(f".{name}", __name__)
# -> 2745 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute 'plot'
