# %%
import torch
import torchvision
from d2l import torch as d2l

from gen_sine_data import SineData

# %%
train_data = SineData(True)
test_data = SineData(False)
# Out:
# 20000
# 19900
# 100
# <class 'torch.Tensor'>
# torch.Size([19900, 100])
# 20000
# 19900
# 100
# <class 'torch.Tensor'>
# torch.Size([19900, 100])

# %%
print(len(train_data), len(test_data))
print(train_data.features.shape, test_data.labels.shape)

time, x = SineData._gen_sine_data()

d2l.plot(time, x, 'time', 'x', xlim=[1, 20000], figsize=(6,3))
# Out:
# 15920 3980
# torch.Size([15920, 100]) torch.Size([3980])
# 20000

# %%
from simple_autoregressor import get_simple_autoregressor

model = get_simple_autoregressor()
# Out:
# 20000
# 19900
# 100
# <class 'torch.Tensor'>
# torch.Size([19900, 100])
# 20000
# 19900
# 100
# <class 'torch.Tensor'>
# torch.Size([19900, 100])
# Loss for epoch 0: 0.0093
# Loss for epoch 1: 0.0040
# Loss for epoch 2: 0.0039
# Loss for epoch 3: 0.0038
# Loss for epoch 4: 0.0037
# Loss for epoch 5: 0.0037
# Loss for epoch 6: 0.0036
# Loss for epoch 7: 0.0036
# Loss for epoch 8: 0.0036
# Loss for epoch 9: 0.0035
# Loss for epoch 10: 0.0035
# Loss for epoch 11: 0.0035
# Loss for epoch 12: 0.0034
# Loss for epoch 13: 0.0034
# Loss for epoch 14: 0.0034
# Loss for epoch 15: 0.0034
# Loss for epoch 16: 0.0034
# Loss for epoch 17: 0.0033
# Loss for epoch 18: 0.0033
# Loss for epoch 19: 0.0033
# Loss for epoch 20: 0.0033
# Loss for epoch 21: 0.0033
# Loss for epoch 22: 0.0033
# Loss for epoch 23: 0.0033
# Loss for epoch 24: 0.0033
# Loss for epoch 25: 0.0032
# Loss for epoch 26: 0.0032
# Loss for epoch 27: 0.0032
# Loss for epoch 28: 0.0032
# Loss for epoch 29: 0.0032
# ...

# %%
pred_train = model(train_data.features).detach().cpu().numpy()
pred_test = model(test_data.features).detach().cpu().numpy()

print(train_data.features.shape)
# Out:
# torch.Size([15920, 100])

# %%
time = train_data.time.detach().cpu().numpy()
x = train_data.x.detach().cpu().numpy()

print(time.shape, x.shape, pred_train.shape)

d2l.plot(time, [x,pred_train], 'time', 'x', legend=['labels', 'preds'], figsize=(6,3))
# Out:
# (15820,) (15820,) (15920,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 6
#       2 x = train_data.x[train_data.tau:].detach().cpu().numpy()
#       4 print(time.shape, x.shape, pred_train.shape)
# ----> 6 d2l.plot(time, [x,pred_train], 'time', 'x', legend=['labels', 'preds'], figsize=(6,3))
#
# File ~/miniconda3/envs/d2l/lib/python3.9/site-packages/d2l/torch.py:98, in plot(X, Y, xlabel, ylabel, legend, xlim, ylim, xscale, yscale, fmts, figsize, axes)
#      96 axes.cla()
#      97 for x, y, fmt in zip(X, Y, fmts):
# ---> 98     axes.plot(x,y,fmt) if len(x) else axes.plot(y,fmt)
#      99 set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend)
#
# File ~/miniconda3/envs/d2l/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
# ...

# %%
d2l.plot(test_data.time.detach().cpu().numpy(), [test_data.x.detach().cpu().numpy(),pred_test], 'time', 'x', legend=['labels', 'preds'], figsize=(6,3))
